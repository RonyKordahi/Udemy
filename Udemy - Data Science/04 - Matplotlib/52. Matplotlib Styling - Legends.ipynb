# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 11)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, x, label = "X")
ax.plot(x, x ** 2, label = "X squared")

ax.legend(loc = (1.01, 0.89));
